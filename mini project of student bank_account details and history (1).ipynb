# %%
import random
class Bank:
    bankname = "sbi bank of india"
    branch = "golegram"
    def __init__(self,username,password,pan_details,address):
        self.username=username
        self.password=password
        self.pan_details=pan_details
        self.address=address
        self.acc_no=random.randint(100000,999999)
        self.balance = 0.0
        self.history=[]
        print (f"\n hello {self.username} your account created successfully")
        print (f" your account no : {self.acc_no} and password : {self.password} created successfully")
    def deposit(self,amount):
        if amount <= 0:
            print("the amount is insufficient")
            return
        self.balance += amount
        self.history.append(f" deposited{amount}")
        print(f" deposited {amount} sucesfully")
    def withdraw(self,amount):
        if amount <= self.balance:
            
            self.balance -= amount
            self.history.append(f" withdrawnn {amount}")
            print(f" {amount} withdrawn sucessfully")
        else:
            print("insufficient balance")
    def ministatement(self):
        
        
         
        print("\n transaction :")
        if not self.history:
             print("no transaction yet")
        else:
             for taxn in self.history:
                 print("-" ,taxn)
             print(f"\n current balance {self.balance}")
username = input("enter your usernamee")
password = input("enter your password is")
pan_details = input("enter your pan_details") 
address = input("enter your addresss")  
b = Bank(username,password,pan_details,address)

while True:
    print("\n please choose an option")
    print("1.deposit")
    print("2.withdraw")
    print("3.ministatement")
    print("4.exit")
    option = int(input("please choose an option 1-4 "))
    if option == 1:
        amount = float(input("enter the deposit amount"))
        b.deposit(amount)
    elif option == 2:
        amount = float(input("enter the withdrawl amount"))
        b.withdraw(amount2)
    elif option == 3:
        b.ministatement()
    elif option == 4:
        print("thank you for banking with us")
        break
